# %%
import pandas as pd

# %%
ayam_df = pd.read_csv("dataset-ayam.csv")
ikan_df = pd.read_csv("dataset-ikan.csv")
kambing_df = pd.read_csv("dataset-kambing.csv")
sapi_df = pd.read_csv("dataset-sapi.csv")
tahu_df = pd.read_csv("dataset-tahu.csv")
telur_df = pd.read_csv("dataset-telur.csv")
tempe_df = pd.read_csv("dataset-tempe.csv")
udang_df = pd.read_csv("dataset-udang.csv")

# %%
del ayam_df["URL"]
del ikan_df["URL"]
del kambing_df["URL"]
del sapi_df["URL"]
del tahu_df["URL"]
del telur_df["URL"]
del tempe_df["URL"]
del udang_df["URL"]

# %%
del ayam_df["Loves"]
del ikan_df["Loves"]
del kambing_df["Loves"]
del sapi_df["Loves"]
del tahu_df["Loves"]
del telur_df["Loves"]
del tempe_df["Loves"]
del udang_df["Loves"]

# %%
ayam_df = ayam_df.drop_duplicates('Title')
ayam_df = ayam_df.dropna()
ayam_df = ayam_df.reset_index(drop=True)

# %%
ikan_df = ikan_df.drop_duplicates('Title')
ikan_df = ikan_df.dropna()
ikan_df = ikan_df.reset_index(drop=True)

kambing_df = kambing_df.drop_duplicates('Title')
kambing_df = kambing_df.dropna()
kambing_df = kambing_df.reset_index(drop=True)

sapi_df = sapi_df.drop_duplicates('Title')
sapi_df = sapi_df.dropna()
sapi_df = sapi_df.reset_index(drop=True)

tahu_df = tahu_df.drop_duplicates('Title')
tahu_df = tahu_df.dropna()
tahu_df = tahu_df.reset_index(drop=True)

telur_df = telur_df.drop_duplicates('Title')
telur_df = telur_df.dropna()
telur_df = telur_df.reset_index(drop=True)

tempe_df = tempe_df.drop_duplicates('Title')
tempe_df = tempe_df.dropna()
tempe_df = tempe_df.reset_index(drop=True)

udang_df = udang_df.drop_duplicates('Title')
udang_df = udang_df.dropna()
udang_df = udang_df.reset_index(drop=True)

# %%
ayam_df
# Out:
#                                  Title  \
# 0                     Ayam Woku Manado
# 1             Ayam goreng tulang lunak
# 2                     Ayam cabai kawin
# 3                          Ayam Geprek
# 4                          Minyak Ayam
# ...                                ...
# 1603       Sayap Ayam Super Pedas 🌶🌶🌶🌶
# 1604                       Ukepan Ayam
# 1605  Chicken Stroganoff with Mushroom
# 1606                  Sop Pangsit Ayam
# 1607                 Ayam Bumbu Bawang
#
#                                             Ingredients  \
# 0     1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1     1 kg ayam (dipotong sesuai selera jangan kecil...
# 2     1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
# 3     250 gr daging ayam (saya pakai fillet)--Secuku...
# 4     400 gr kulit ayam & lemaknya--8 siung bawang p...
# ...                                                 ...
# 1603  6 buah sayap ayam, belah jadi 2--1 ruas jahe--...
# ...

# %%
ikan_df
# Out:
#                                          Title  \
# 0                           Gurame Saus Padang
# 1                    Ikan Kembung Bakar Teflon
# 2                      Mujaer asam pedas manis
# 3                            Gurame Asam manis
# 4                         Asam padeh ikan tuna
# ...                                        ...
# 1796     Mie rebus tongkol suwir ala neng tika
# 1797  Tongkol pecak sambel korek ala neng tika
# 1798                      Lele frozen berbumbu
# 1799                        Gurami saus padang
# 1800                 Kepala Kakap Masak Kuning
#
#                                             Ingredients  \
# 0     Bahan utama:--1 ekor gurame--Bumbu untuk saus:...
# 1     1/2 kg ikan kembung sate, bersihkan--1 buah je...
# 2     1/2 kg ikan mujaer (stok gurame habis)--2 buah...
# 3     1/2 kg ikan gurame--2 buah wortel (potong sepe...
# 4     1/2 kg ikan tuna--6 siung bawang merah--4 siun...
# ...

# %%
kambing_df
# Out:
#                                     Title  \
# 0                           .Sate Kambing
# 1                           Rabeg Kambing
# 2                           Gulai kambing
# 3                    Sayur tulang kambing
# 4                            Sate Kambing
# ...                                   ...
# 1496               Sambal Ijo Jambal Roti
# 1497                   Nasi goreng jeroan
# 1498  Beef Bowl / rice Bowl ala yoshinoya
# 1499                  Tongseng Kambiang 🐐
# 1500                      Yogurt Handmade
#
#                                             Ingredients  \
# 0     Bahan-bahan :--500 gr Daging kambing--Daun pep...
# 1     1 kg daging kambing bagian paha beserta tulang...
# 2     500 gram daging kambing--Bumbu :--sesuai seler...
# 3     1.5 kg tulang sumsum kambing(direbus dahulu)ag...
# 4     300 garam daging kambing--1/2 buah jeruk nipis...
# ...                                                 ...
# 1496  secukupnya ikan asin jambal roti--200 gr cabai...
# ...

# %%
sapi_df
# Out:
#                                                   Title  \
# 0                                         Beef Teriyaki
# 1                                          Rendang Sapi
# 2                            Tongseng daging sapi pedas
# 3                                     Semur Daging Sapi
# 4                                  Tongseng daging sapi
# ...                                                 ...
# 1535                        Steak daging sapi (rumahan)
# 1536                       Oseng kikil sapi pedas manis
# 1537  Bistik sapi empuk. Dengan tips memasak daging ...
# 1538                               Sayur godog Iga sapi
# 1539                   Sop sayur tetelan daging sapi 🐄🐮
#
#                                             Ingredients  \
# 0     250 gr daging sapi--1 siung bawang bombai--5 s...
# 1     1 kg daging sapi--4 butir kelapa untuk 2L sant...
# 2     300 gr daging sapi (iris tipis panjang)--Bumbu...
# 3     1/2 kg daging sapi--1 biji bawang bombay--2 si...
# ...

# %%
tahu_df
# Out:
#                                                   Title  \
# 0                      Martabak tahu pedas kulit lumpia
# 1     Batagor (Bakso Tahu Goreng) ala rumahan anti g...
# 2                         Sayur Sutace (sop tahu ceker)
# 3                               Sapo Tahu Ayam ala Mey👌
# 4             TTKK (tahu telur timun tauge kuah kacang)
# ...                                                 ...
# 1662                                 Semur Pindang Tahu
# 1663                                    Ayam siram tahu
# 1664                                       Tahu KW DEBM
# 1665                          Tahu goreng krispi simple
# 1666                                  Tahu masak kuning
#
#                                             Ingredients  \
# 0     12 lembar kulit lumpia--4 buah tahu putih--2 b...
# 1     Bahan batagor--3 kotak ukuran kecil tahu kunin...
# 2     1/2 kg ceker ayam--4 buah wortel ukuran sedang...
# 3     1 bks Tofu--5-10 bh filet ayam--1 bh wortel, i...
# ...

# %%
telur_df
# Out:
#                                       Title  \
# 0                    Orak arik telur buncis
# 1                    Terik ayam tempe telor
# 2                              Telur Kornet
# 3                       Tahu telur surabaya
# 4                  Telur ceplok masak kecap
# ...                                     ...
# 1761                    Semur telor tempe 😉
# 1762               Kukus telor tahu pedas 🍽
# 1763  Telur rebus isi (filling boiled eggs)
# 1764     Sup tomat dan telur,menu sederhana
# 1765                   Dadar Telur Cah Toge
#
#                                             Ingredients  \
# 0     1 buah telur--10 buncis--3 bawang merah--2 baw...
# 1     4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2     1/2 kaleng kornet--2-3 buah bawang prei--2 bua...
# 3     1 butir telur--1 potong tahu putih goreng sete...
# 4     4 butir telur--4 siung bwng merah--2 siung bwn...
# ...                                                 ...
# ...

# %%
tempe_df
# Out:
#                                     Title  \
# 0     Orek tempe manis pedas super simple
# 1                  Terik ayam tempe telor
# 2       Penyet Tempe Sambel Korek Kemangi
# 3                            Nugget tempe
# 4                     Tempe tepung sajiku
# ...                                   ...
# 1582              Tahu Tempe Telur Balado
# 1583      Lodeh putih tempe gembos😄 pedes
# 1584              Tempe mendol jawa timur
# 1585               Oseng tempe Lombok ijo
# 1586              Tahu tempe bumbu kuning
#
#                                             Ingredients  \
# 0     Tempe (saya beli 3000 saja)--3 buah cabe gendo...
# 1     4 sayap ayam--4 buah telor--1/2 papan tempe--B...
# 2     2 buah tempe--1 genggam Daun kemangi--15 cabe ...
# 3     1 papan tempe dihaluskan(saya kukus dlu)--1 bu...
# 4     1 potong tempe 3000--1 bngkus sajiku tepung se...
# ...                                                 ...
# 1582  5 buah tahu--1 buah tempe yg besar potong mema...
# ...

# %%
udang_df
# Out:
#                                   Title  \
# 0       Lumpia udang kulit tahu ala fe'
# 1                 Bakso Ayam Udang Keto
# 2                    Udang ala pop corn
# 3                Bakwan Udang Sederhana
# 4         Udang Goreng Tepung Mayonaise
# ...                                 ...
# 1613     Udang tepung dengan saus kecap
# 1614                 Jipang tumis udang
# 1615                  Tumis Udang Tempe
# 1616  Tumis kacang panjang terong udang
# 1617                  Siomay Udang Ayam
#
#                                             Ingredients  \
# 0     50 gram ayam potong kotak kecil--200 gram udan...
# 1     400 gr ayam giling--250 gr udang kupas--3 telu...
# 2     1/4 kg udang basah ukuran sedang--1 bungkus ko...
# 3     1/2 kg Tepung terigu (sudah di ayak)--1/2 Udan...
# 4     300 gr udang (buang kepalanya)--Jeruk nipis--T...
# ...                                                 ...
# 1613  Bahan:--300 gr Udang--1 btr Telur--Bumbu:--3 t...
# ...

# %%
ayam_df = ayam_df.iloc[:-1558]

# %%
ayam_df = ayam_df.drop(index=10)

# %%
ayam_df = ayam_df.reset_index(drop=True)

# %%
ikan_df = ikan_df.iloc[:-1751]
kambing_df = kambing_df.iloc[:-1451]
sapi_df = sapi_df.iloc[:-1490]
tahu_df = tahu_df.iloc[:-1617]
telur_df = telur_df.iloc[:-1716]
tempe_df = tempe_df.iloc[:-1537]
udang_df = udang_df.iloc[:-1568]

# %%
ikan_df
# Out:
#                                            Title  \
# 0                             Gurame Saus Padang
# 1                      Ikan Kembung Bakar Teflon
# 2                        Mujaer asam pedas manis
# 3                              Gurame Asam manis
# 4                           Asam padeh ikan tuna
# 5                             Avocado Tuna Salad
# 6                                Lele Asam Manis
# 7                     Pempek kulit ikan tenggiri
# 8                            Tumis Tongkol Petai
# 9                         Ikan Patin pedas manis
# 10                             Gurame tahu tauco
# 11                                    Ikan Patin
# 12         2. Gulai Ikan Kakap Merah khas Padang
# 13       Gurame crispy asam manis ala amih fatih
# 14                         Balado Tongkol & Tahu
# 15                            Balado Ikan Sarden
# 16             Ikan Nila (saos pedas asam manis)
# 17                             Sarden kangkung 😘
# ...

# %%
ikan_df = ikan_df.drop(index=27)
ikan_df = ikan_df.reset_index(drop=True)

# %%
ikan_df
# Out:
#                                            Title  \
# 0                             Gurame Saus Padang
# 1                      Ikan Kembung Bakar Teflon
# 2                        Mujaer asam pedas manis
# 3                              Gurame Asam manis
# 4                           Asam padeh ikan tuna
# 5                             Avocado Tuna Salad
# 6                                Lele Asam Manis
# 7                     Pempek kulit ikan tenggiri
# 8                            Tumis Tongkol Petai
# 9                         Ikan Patin pedas manis
# 10                             Gurame tahu tauco
# 11                                    Ikan Patin
# 12         2. Gulai Ikan Kakap Merah khas Padang
# 13       Gurame crispy asam manis ala amih fatih
# 14                         Balado Tongkol & Tahu
# 15                            Balado Ikan Sarden
# 16             Ikan Nila (saos pedas asam manis)
# 17                             Sarden kangkung 😘
# ...

# %%
ikan_df = ikan_df.drop(index=48)
ikan_df = ikan_df.reset_index(drop=True)

# %%
kambing_df
# Out:
#                                                 Title  \
# 0                                       .Sate Kambing
# 1                                       Rabeg Kambing
# 2                                       Gulai kambing
# 3                                Sayur tulang kambing
# 4                                        Sate Kambing
# 5                                    Sop Kaki Kambing
# 6                              Kari kambing ala bundo
# 7                             Tongseng kambing presto
# 8                            Telor dadar otak kambing
# 9              Sate kambing siram sambal bawang kecap
# 10                           Gule kambing pedas #keto
# 11                              Sate Kambing Maranggi
# 12                          Soto babat kambing madura
# 13                   Oseng-oseng tulang kambing pedas
# 14                                   Tongseng kambing
# 15                                      Gulai Kambing
# ...

# %%
ikan_df
# Out:
#                                            Title  \
# 0                             Gurame Saus Padang
# 1                      Ikan Kembung Bakar Teflon
# 2                        Mujaer asam pedas manis
# 3                              Gurame Asam manis
# 4                           Asam padeh ikan tuna
# 5                             Avocado Tuna Salad
# 6                                Lele Asam Manis
# 7                     Pempek kulit ikan tenggiri
# 8                            Tumis Tongkol Petai
# 9                         Ikan Patin pedas manis
# 10                             Gurame tahu tauco
# 11                                    Ikan Patin
# 12         2. Gulai Ikan Kakap Merah khas Padang
# 13       Gurame crispy asam manis ala amih fatih
# 14                         Balado Tongkol & Tahu
# 15                            Balado Ikan Sarden
# 16             Ikan Nila (saos pedas asam manis)
# 17                             Sarden kangkung 😘
# ...

# %%
kambing_df = kambing_df.drop(index= [0, 2, 7, 14, 18, 20, 36, 39, 44])
kambing_df = kambing_df.reset_index(drop=True)

# %%
kambing_df
# Out:
#                                                 Title  \
# 0                                       Rabeg Kambing
# 1                                Sayur tulang kambing
# 2                                        Sate Kambing
# 3                                    Sop Kaki Kambing
# 4                              Kari kambing ala bundo
# 5                            Telor dadar otak kambing
# 6              Sate kambing siram sambal bawang kecap
# 7                            Gule kambing pedas #keto
# 8                               Sate Kambing Maranggi
# 9                           Soto babat kambing madura
# 10                   Oseng-oseng tulang kambing pedas
# 11                                      Gulai Kambing
# 12              Oseng kambing kecap asam manis simple
# 13                                   Tongseng Kambing
# 14                     Balado kentang dan ati kambing
# 15              Kambing goreng simple with kecap cabe
# ...

# %%
sapi_df
# Out:
#                                                 Title  \
# 0                                       Beef Teriyaki
# 1                                        Rendang Sapi
# 2                          Tongseng daging sapi pedas
# 3                                   Semur Daging Sapi
# 4                                Tongseng daging sapi
# 5                         Beef black pepper spaghetti
# 6                     Carbonara Linguine smooked beef
# 7                                  Semur Jantung Sapi
# 8               Daging sapi cincang taousi cah buncis
# 9                 Sayur asem kacang merah daging sapi
# 10                        Orak arik telur daging sapi
# 11                              Se'i Sapi Khas Kupang
# 12                              Beef steak saus jamur
# 13                                  Tumis Daging Sapi
# 14                              Bola-Bola Kornet Sapi
# 15               Sayur sop daging sapi no MSG no Gula
# ...

# %%
sapi_df = sapi_df.drop(index= [16, 45])
sapi_df = sapi_df.reset_index(drop=True)

# %%
tahu_df
# Out:
#                                                 Title  \
# 0                    Martabak tahu pedas kulit lumpia
# 1   Batagor (Bakso Tahu Goreng) ala rumahan anti g...
# 2                       Sayur Sutace (sop tahu ceker)
# 3                             Sapo Tahu Ayam ala Mey👌
# 4           TTKK (tahu telur timun tauge kuah kacang)
# 5                      Perkedel Tahu Wortel Sederhana
# 6                             Kari tahu telur kentang
# 7          Sundubu Jjigae (sup tahu pedas ala2 korea)
# 8                     Nugget Tahu Ekonomis Anti Gagal
# 9                               Tahu Petis musim ujan
# 10                                 Sayur tahu jengkol
# 11                               Sapo Tahu No Seafood
# 12                                         Tahu Bulat
# 13                             Tahu kuning lada garam
# 14                                Pepes Tahu kekinian
# 15                                         Mung tahu'
# ...

# %%
tahu_df = tahu_df.drop(index= [0,3, 4, 7])
tahu_df = tahu_df.reset_index(drop=True)

# %%
tahu_df
# Out:
#                                                 Title  \
# 0   Batagor (Bakso Tahu Goreng) ala rumahan anti g...
# 1                       Sayur Sutace (sop tahu ceker)
# 2                      Perkedel Tahu Wortel Sederhana
# 3                             Kari tahu telur kentang
# 4                     Nugget Tahu Ekonomis Anti Gagal
# 5                               Tahu Petis musim ujan
# 6                                  Sayur tahu jengkol
# 7                                Sapo Tahu No Seafood
# 8                                          Tahu Bulat
# 9                              Tahu kuning lada garam
# 10                                Pepes Tahu kekinian
# 11                                         Mung tahu'
# 12                                  Sapo Tahu Brokoli
# 13                                      Tahu isi Enak
# 14                              Balado Tongkol & Tahu
# 15                                    Tahu cabe garam
# ...

# %%
telur_df
# Out:
#                                                 Title  \
# 0                              Orak arik telur buncis
# 1                              Terik ayam tempe telor
# 2                                        Telur Kornet
# 3                                 Tahu telur surabaya
# 4                            Telur ceplok masak kecap
# 5                                   Sambal telur ayam
# 6                                  Telur Dadar Padang
# 7                        Ceplok Telor saus Asam Manis
# 8                            Potatoes cheese with egg
# 9           TTKK (tahu telur timun tauge kuah kacang)
# 10                         Semur kering telur kentang
# 11                            Kari tahu telur kentang
# 12                                   Buncis Cah Telur
# 13                                    Telur cah tomat
# 14                        Cah sawi putih campur telur
# 15                            Telur Tahu Kukus Goreng
# ...

# %%
telur_df = telur_df.drop(index= [39, 36, 46])
telur_df = telur_df.reset_index(drop=True)

# %%
sapi_df
# Out:
#                                                 Title  \
# 0                                       Beef Teriyaki
# 1                                        Rendang Sapi
# 2                          Tongseng daging sapi pedas
# 3                                   Semur Daging Sapi
# 4                                Tongseng daging sapi
# 5                         Beef black pepper spaghetti
# 6                     Carbonara Linguine smooked beef
# 7                                  Semur Jantung Sapi
# 8               Daging sapi cincang taousi cah buncis
# 9                 Sayur asem kacang merah daging sapi
# 10                        Orak arik telur daging sapi
# 11                              Se'i Sapi Khas Kupang
# 12                              Beef steak saus jamur
# 13                                  Tumis Daging Sapi
# 14                              Bola-Bola Kornet Sapi
# 15               Sayur sop daging sapi no MSG no Gula
# ...

# %%
sapi_df = sapi_df.drop(index= [0, 6, 5, 42, 38, 33, 35, 28, 20, 18, 17, 12])
sapi_df = sapi_df.reset_index(drop=True)

# %%
sapi_df
# Out:
#                                              Title  \
# 0                                     Rendang Sapi
# 1                       Tongseng daging sapi pedas
# 2                                Semur Daging Sapi
# 3                             Tongseng daging sapi
# 4                               Semur Jantung Sapi
# 5            Daging sapi cincang taousi cah buncis
# 6              Sayur asem kacang merah daging sapi
# 7                      Orak arik telur daging sapi
# 8                            Se'i Sapi Khas Kupang
# 9                                Tumis Daging Sapi
# 10                           Bola-Bola Kornet Sapi
# 11            Sayur sop daging sapi no MSG no Gula
# 12                           Asem asem daging sapi
# 13                    Lumpia isi daging sapi & kol
# 14                              Oseng Tetelan Sapi
# 15                                   Tongseng sapi
# 16                  Soto Daging Sapi Lobak& Wortel
# ...

# %%
ayam_df
# Out:
#                                       Title  \
# 0                          Ayam Woku Manado
# 1                  Ayam goreng tulang lunak
# 2                          Ayam cabai kawin
# 3                               Ayam Geprek
# 4                               Minyak Ayam
# 5                           Nasi Bakar Ayam
# 6                   Ayam Saus Hintalu Jaruk
# 7             Ayam saos teriyaki Lada Hitam
# 8                                Steak ayam
# 9               Ayam Saos Asam Manis Simple
# 10  Ayam Bakar Pedas Manis Resep :Nila Sari
# 11       Semur Ayam Kentang Ala Mama Kirana
# 12                               Ayam suwir
# 13                       Ayam goreng tepung
# 14                  Tulang Ayam Pedas Manis
# 15                      Ayam penyet rumahan
# 16                                 Sop ayam
# 17                    Nugget Ayam Home Made
# 18                              Ayam Koloke
# 19                          Mie tulang ayam
# ...

# %%
ayam_df = ayam_df.drop(index= [45, 37, 26,8, 17, 27, 43])
ayam_df = ayam_df.reset_index(drop=True)

# %%
ayam_df
# Out:
#                                       Title  \
# 0                          Ayam Woku Manado
# 1                  Ayam goreng tulang lunak
# 2                          Ayam cabai kawin
# 3                               Ayam Geprek
# 4                               Minyak Ayam
# 5                           Nasi Bakar Ayam
# 6                   Ayam Saus Hintalu Jaruk
# 7             Ayam saos teriyaki Lada Hitam
# 8               Ayam Saos Asam Manis Simple
# 9   Ayam Bakar Pedas Manis Resep :Nila Sari
# 10       Semur Ayam Kentang Ala Mama Kirana
# 11                               Ayam suwir
# 12                       Ayam goreng tepung
# 13                  Tulang Ayam Pedas Manis
# 14                      Ayam penyet rumahan
# 15                                 Sop ayam
# 16                              Ayam Koloke
# 17                          Mie tulang ayam
# 18           Ayam Suir Bali (bemesere bali)
# 19                       Pindang ayam jadul
# ...

# %%
ikan_df
# Out:
#                                            Title  \
# 0                             Gurame Saus Padang
# 1                      Ikan Kembung Bakar Teflon
# 2                        Mujaer asam pedas manis
# 3                              Gurame Asam manis
# 4                           Asam padeh ikan tuna
# 5                             Avocado Tuna Salad
# 6                                Lele Asam Manis
# 7                     Pempek kulit ikan tenggiri
# 8                            Tumis Tongkol Petai
# 9                         Ikan Patin pedas manis
# 10                             Gurame tahu tauco
# 11                                    Ikan Patin
# 12         2. Gulai Ikan Kakap Merah khas Padang
# 13       Gurame crispy asam manis ala amih fatih
# 14                         Balado Tongkol & Tahu
# 15                            Balado Ikan Sarden
# 16             Ikan Nila (saos pedas asam manis)
# 17                             Sarden kangkung 😘
# ...

# %%
ikan_df = ikan_df.drop(index= [5, 13, 25, 34])
ikan_df = ikan_df.reset_index(drop=True)

# %%
kambing_df
# Out:
#                                                 Title  \
# 0                                       Rabeg Kambing
# 1                                Sayur tulang kambing
# 2                                        Sate Kambing
# 3                                    Sop Kaki Kambing
# 4                              Kari kambing ala bundo
# 5                            Telor dadar otak kambing
# 6              Sate kambing siram sambal bawang kecap
# 7                            Gule kambing pedas #keto
# 8                               Sate Kambing Maranggi
# 9                           Soto babat kambing madura
# 10                   Oseng-oseng tulang kambing pedas
# 11                                      Gulai Kambing
# 12              Oseng kambing kecap asam manis simple
# 13                                   Tongseng Kambing
# 14                     Balado kentang dan ati kambing
# 15              Kambing goreng simple with kecap cabe
# ...

# %%
kambing_df = kambing_df.drop(index= [7, 26, 28, 36, 38])
kambing_df = kambing_df.reset_index(drop=True)

# %%
tempe_df
# Out:
#                                                 Title  \
# 0                 Orek tempe manis pedas super simple
# 1                              Terik ayam tempe telor
# 2                   Penyet Tempe Sambel Korek Kemangi
# 3                                        Nugget tempe
# 4                                 Tempe tepung sajiku
# 5                                         Patty Tempe
# 6                Orek tempe basah bumbu ulek (recook)
# 7                                      Perkedel Tempe
# 8                                 Nugget Tempe Simple
# 9          Sarden ikan pindang tempe pedas adam manis
# 10                                 Tempe Isi Kekinian
# 11            Sayur Lodeh Tempe Semangit (Bumbu Ulek)
# 12                                      Tempe mendoan
# 13                                Bacem tempe mentega
# 14                   Sayur tempe mix tahu alaala kari
# 15                              Tempe goreng segitiga
# ...

# %%
tempe_df = tempe_df.drop(index= [5, 14, 22, 30, 37, 31])
tempe_df = tempe_df.reset_index(drop=True)

# %%
udang_df
# Out:
#                                       Title  \
# 0           Lumpia udang kulit tahu ala fe'
# 1                     Bakso Ayam Udang Keto
# 2                        Udang ala pop corn
# 3                    Bakwan Udang Sederhana
# 4             Udang Goreng Tepung Mayonaise
# 5                     Udang saus asam manis
# 6                         Tekwan Kuah Udang
# 7                       Sambal udang goreng
# 8                  Udang asam manis oregano
# 9                  Tumis buncis pakai udang
# 10                        Udang saos padang
# 11                     Udang Goreng Mentega
# 12                     Udang goreng mentega
# 13                        Udang pete balado
# 14                         Bakso udang debm
# 15                    Oseng Udang Pedas 🍤🌶️
# 16                      Udang Goreng Tepung
# 17                      Udang goreng tepung
# 18                         Udang asam manis
# 19                    Udang Saus Telor Asin
# ...

# %%
udang_df = udang_df.drop(index= [0, 2, 37, 24, 20,15, 12, 4, 17, 8, 18, 26, 42, 23])
udang_df = udang_df.reset_index(drop=True)

# %%
merged_dataset = pd.concat([ayam_df, ikan_df, kambing_df, sapi_df, tahu_df, telur_df, tempe_df, udang_df])
merged_dataset.shape
# Out:
# (331, 3)

# %%
merged_dataset
# Out:
#                             Title  \
# 0                Ayam Woku Manado
# 1        Ayam goreng tulang lunak
# 2                Ayam cabai kawin
# 3                     Ayam Geprek
# 4                     Minyak Ayam
# ..                            ...
# 31                 Perkedel Udang
# 32  Tumis tempe, udang,ati ampela
# 33              Sambel udang pete
# 34              Cah udang dan kol
# 35   Tumis Udang saos tiram pedas
#
#                                           Ingredients  \
# 0   1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1   1 kg ayam (dipotong sesuai selera jangan kecil...
# 2   1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
# 3   250 gr daging ayam (saya pakai fillet)--Secuku...
# 4   400 gr kulit ayam & lemaknya--8 siung bawang p...
# ..                                                ...
# 31  1 kg kentang--3 telur ayam--Udang kupas sisaka...
# 32  1/4 udang--4 papan tempe uk kecil--2 pasang at...
# 33  250 gr Udang Kupas (Belah Punggung udang)--100...
# ...

# %%
merged_dataset.to_csv("preprocessed_recido.csv", index = False)

# %%
import pandas as pd

# %%
recido_df = pd.read_csv("preprocessed_recido.csv")

# %%
recido_df = recido_df.drop_duplicates('Title')
recido_df = recido_df.dropna()
recido_df = recido_df.reset_index(drop=True)

# %%
recido_df
# Out:
#                              Title  \
# 0                 Ayam Woku Manado
# 1         Ayam goreng tulang lunak
# 2                 Ayam cabai kawin
# 3                      Ayam Geprek
# 4                      Minyak Ayam
# ..                             ...
# 315                 Perkedel Udang
# 316  Tumis tempe, udang,ati ampela
# 317              Sambel udang pete
# 318              Cah udang dan kol
# 319   Tumis Udang saos tiram pedas
#
#                                            Ingredients  \
# 0    1 Ekor Ayam Kampung (potong 12)--2 Buah Jeruk ...
# 1    1 kg ayam (dipotong sesuai selera jangan kecil...
# 2    1/4 kg ayam--3 buah cabai hijau besar--7 buah ...
# 3    250 gr daging ayam (saya pakai fillet)--Secuku...
# 4    400 gr kulit ayam & lemaknya--8 siung bawang p...
# ..                                                 ...
# 315  1 kg kentang--3 telur ayam--Udang kupas sisaka...
# 316  1/4 udang--4 papan tempe uk kecil--2 pasang at...
# ...

# %%
recido_df.to_csv("recido.csv", index = False)
